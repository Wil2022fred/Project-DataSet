# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticswithadam/Python/blob/main/YouTube_Comments_Advanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dev = "AIzaSyCGA3bOaw-d9cg84LmLftuTFgG2527j404"

# %%
# How novel coronavirus spread through the Shincheonji religious group in South Korea
# https://youtu.be/G17YExUcSj0?si=JlmpwCtSI6vt9Nac
#https://youtu.be/ZKC7bYTLBP0?si=Zff6vm-gM1FEtPVr
# https://youtu.be/G17YExUcSj0?si=JlmpwCtSI6vt9Nac
#https://youtu.be/ZKC7bYTLBP0?si=Zff6vm-gM1FEtPVr
#https://youtu.be/93UFsSCD-Go?si=OMLN4b4Wip0VOs_E 
#https://youtu.be/CmjnJX5dwaM?si=R9cq1QpQpDE0lS2v
# Singer Kim Ho-joong faces hit-and-run, drunk driving, driver swap allegations
# https://youtu.be/0fMeCKgYWrQ?si=JNaw621geueQd4NI
# https://youtu.be/yXQNK1-A4B0?si=1nr9m8LZ0IgojG9k
videos = ["G17YExUcSj0","ZKC7bYTLBP0","93UFsSCD-Go","CmjnJX5dwaM","0fMeCKgYWrQ","yXQNK1-A4B0"]

# %% [markdown]
# ## Pull All Comments

# %%
import googleapiclient.discovery
import pandas as pd
for  videoID in videos:

    api_service_name = "youtube"
    api_version = "v3"
    DEVELOPER_KEY = dev
    
    youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey=DEVELOPER_KEY)
    
    request = youtube.commentThreads().list(
        part="snippet",
        videoId="G17YExUcSj0",
        maxResults=100
    )
    comments = []
    # Execute the request.
    response = request.execute()
    
    # Get the comments from the response.
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        public = item['snippet']['isPublic']
        comments.append([
            comment['authorDisplayName'],
            comment['publishedAt'],
            comment['likeCount'],
            comment['textOriginal'],
            public
        ])
    
    while (1 == 1):
      try:
       nextPageToken = response['nextPageToken']
      except KeyError:
       break
      nextPageToken = response['nextPageToken']
      # Create a new request object with the next page token.
      nextRequest = youtube.commentThreads().list(part="snippet", videoId="G17YExUcSj0", maxResults=100, pageToken=nextPageToken)
      # Execute the next request.
      response = nextRequest.execute()
      # Get the comments from the next response.
      for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        public = item['snippet']['isPublic']
        comments.append([
            comment['authorDisplayName'],
            comment['publishedAt'],
            comment['likeCount'],
            comment['textOriginal'],
            public
        ])
    
    df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
    df

# %%
comments
# Out:
# [['@user-il6bb3hf6s',
#   '2022-11-28T05:35:52Z',
#   0,
#   '유감그만표현하고 정신차려라 멍청도야 합죽이영감을위해 거짓인생 살고싶냐',
#   True],
#  ['@user-qe1cn3ql9t', '2022-06-13T12:12:17Z', 0, '지 랄 하 네', True],
#  ['@user-vr7ec5nl6y',
#   '2022-05-21T14:49:43Z',
#   0,
#   '신천지에 대한 오해가 풀어졌습니다. 감사합니다.',
#   True],
#  ['@user-gc4uq6rn2k',
#   '2022-02-22T06:01:10Z',
#   0,
#   '느그 신천지들이 불 지르고 개신교들이 부채질 하고 마이클조 기름 부어서 불길이 거세져서 화상 입은 피해자들은 의료진 분들과 자영업 하시는 분들이지ㅉㅉㅡㅡ',
#   True],
#  ['@user-wd4ue5fd6b',
#   '2022-01-24T16:24:13Z',
#   0,
#   '지금은 7천명이 넘고 전국적으로 늘어나고 있는데,,,모두가 조심해야한다\n위험한데도 다 일상생활하고 \n속이는 교회들 많고\n지금까지 멈춘곳은 신천지 뿐이더라,,,',
#   True],
#  ['@user-rd7wh1pg7v', '2021-12-18T05:50:11Z', 0, '대단하다 ㅋㅋㅋㅋ', True],
#  ['@freesia4597',
#   '2021-11-16T16:28:11Z',
#   1,
#   '코로나 팬데믹 시작을 성대하게 열었던 집단..!!',
#   True],
#  ['@user-mj5ls4yv8o', '2021-09-09T02:32:03Z', 0, '아 .. 그렇군요..!', True],
#  ['@user-og5ei5mz3s', '2021-09-06T05:04:24Z', 0, '지금 현재 젤 잘하고 있는곳', True],
# ...

# %%
response['items'][0]

# %%
df.head(5)

# %% [markdown]
# ## Sort by Likes and Get Top 10

# %%
df.sort_values(by='like_count', ascending=False)[0:10]

# %% [markdown]
# #Pull all Comments for Multiple Videos

# %% [markdown]
# ## 1. Get Comments Function

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)


def getcomments(video):
  request = youtube.commentThreads().list(
      part="snippet",
      videoId=video,
      maxResults=100
  )

  comments = []

  # Execute the request.
  response = request.execute()

  # Get the comments from the response.
  for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  while (1 == 1):
    try:
     nextPageToken = response['nextPageToken']
    except KeyError:
     break
    nextPageToken = response['nextPageToken']
    # Create a new request object with the next page token.
    nextRequest = youtube.commentThreads().list(part="snippet", videoId=video, maxResults=100, pageToken=nextPageToken)
    # Execute the next request.
    response = nextRequest.execute()
    # Get the comments from the next response.
    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

    df2 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','video_id','public'])
    return df2

# %%
# df = get.comments('G17YExUcSj0')    #('TYxqBTdOq24')
df2
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %% [markdown]
# ## 2. For Loop for List of IDs

# %%
df = pd.DataFrame()
for i in ['G17YExUcSj0','ZKC7bYTLBP0','93UFsSCD-Go','CmjnJX5dwaM']:
  df2 = getcomments(i)
  df = pd.concat([df, df2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22424\3327507617.py in <module>
#       1 df = pd.DataFrame()
#       2 for i in ['G17YExUcSj0','ZKC7bYTLBP0','93UFsSCD-Go','CmjnJX5dwaM']:
# ----> 3   df2 = getcomments(i)
#       4   df = pd.concat([df, df2])
#
# ~\AppData\Local\Temp\ipykernel_22424\1693813013.py in getcomments(video)
#      32           comment['textOriginal'],
#      33           comment['videoId'],
# ---> 34           comment['video_details'],
#      35           comment['comments'],
#      36           comment['transcript'],
#
# KeyError: 'video_details'

# %%
df

# %%
df['video_id'].value_counts()
# Out:
# video_id
# 93UFsSCD-Go    13203
# CmjnJX5dwaM    10477
# G17YExUcSj0     3552
# ZKC7bYTLBP0     1367
# Name: count, dtype: int64

# %%
df.to_csv("Korean_videos.csv")

# %%
//*[@id="mount_0_0_ie"]/div/div[1]/div/div[3]/div/div/div[1]/div[1]/div/div/div[4]/div[2]/div/div[2]/div[1]/div/div/div
//div[@class="x9f619 x1n2onr6 x1ja2u2z x78zum5 x2lah0s x1qughib x1qjc9v5 xozqiw3 x1q0g3np x1pi30zi x1swvt13 xexx8yu xykv574 xbmpl8g x4cne27 xifccgj"] 

//span[text()='About']
